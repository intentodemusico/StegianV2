# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import os, random, time, MirandaAttributes, sys
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import backend as K
from tensorflow.keras import layers, models, callbacks
from sklearn.model_selection import train_test_split, KFold

# %%
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
print("TensorFlow version: {}".format(tf.__version__))
print("Eager execution: {}".format(tf.executing_eagerly()))
#Old dataset
#train_dataset_url = "https://raw.githubusercontent.com/intentodemusico/Stegonomono/master/ANN/Dataset/train_70000.csv"
#test_dataset_url = "https://raw.githubusercontent.com/intentodemusico/Stegonomono/master/ANN/Dataset/test_70000.csv"

#Miranda images, García attributes V2
train_dataset_url = "https://raw.githubusercontent.com/intentodemusico/StegianV2/master/DatasetStegonomonoV2/train_5000.csv"
test_dataset_url = "https://raw.githubusercontent.com/intentodemusico/StegianV2/master/DatasetStegonomonoV2/test_5000.csv"
# Out:
# TensorFlow version: 2.3.0
# Eager execution: True

# %%
#%% Importing the dataset stegonomono V2
Labels=['Kurtosis', 'Skewness', 'Std', 'Range', 'Median', 'Garcia_Geomean', 'Epsilon_Geomean','Mobility', 'Complexity']
trainDataset = pd.read_csv(train_dataset_url,header=None)
X_train = pd.DataFrame(trainDataset.iloc[:, :-1].values,columns=Labels)
X_train["Kurtosis"]=[float(x[1:-1]) for x in X_train["Kurtosis"]]
Y_train = trainDataset.iloc[:, -1].values


testDataset = pd.read_csv(test_dataset_url,header=None)
X_test = pd.DataFrame(testDataset.iloc[:, :-1].values,columns=Labels)
X_test["Kurtosis"]=[float(x[1:-1]) for x in X_test["Kurtosis"]]
Y_test = testDataset.iloc[:, -1].values

# %% [markdown]
# #%% Feature Scaling
# from sklearn.model_selection import train_test_split
# X_train, X_test, Y_Train, Y_Test = train_test_split(x, y, test_size=0.20, random_state=42)
# from sklearn.preprocessing import StandardScaler
# sc.fit_transform(

# %%
sc = StandardScaler()
X_Train = sc.fit_transform(X_train)
X_Test = sc.transform(X_test)

# %%
model = tf.keras.Sequential([
  tf.keras.layers.Dense(9, activation=tf.nn.relu, input_shape=(9,)),  # input shape required
  tf.keras.layers.Dense(5, activation=tf.nn.relu),
  tf.keras.layers.Dense(2, activation=tf.nn.relu),
  tf.keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

model.fit(X_Train, Y_train, batch_size = 64, epochs = 250)
# Out:
# Epoch 1/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6671 - accuracy: 0.5425
# Epoch 2/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.6063 - accuracy: 0.7455
# Epoch 3/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.5624 - accuracy: 0.7995
# Epoch 4/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.5325 - accuracy: 0.8238
# Epoch 5/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.5076 - accuracy: 0.8370
# Epoch 6/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4846 - accuracy: 0.8465
# Epoch 7/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4647 - accuracy: 0.8485
# Epoch 8/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4460 - accuracy: 0.8540
# Epoch 9/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4282 - accuracy: 0.8600
# Epoch 10/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4125 - accuracy: 0.8648
# Epoch 11/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3971 - accuracy: 0.8705
# Epoch 12/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3830 - accuracy: 0.8783
# Epoch 13/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3691 - accuracy: 0.8780
# Epoch 14/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3568 - accuracy: 0.8857
# Epoch 15/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3447 - accuracy: 0.8892
# Epoch 16/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3335 - accuracy: 0.8915
# Epoch 17/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3222 - accuracy: 0.9003
# Epoch 18/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3126 - accuracy: 0.9022
# Epoch 19/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3026 - accuracy: 0.9057
# Epoch 20/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2938 - accuracy: 0.9103
# Epoch 21/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2853 - accuracy: 0.9135
# Epoch 22/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2782 - accuracy: 0.9143
# Epoch 23/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2701 - accuracy: 0.9183
# Epoch 24/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2632 - accuracy: 0.9187
# Epoch 25/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2571 - accuracy: 0.9205
# Epoch 26/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2518 - accuracy: 0.9230
# Epoch 27/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.2470 - accuracy: 0.9237
# Epoch 28/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2411 - accuracy: 0.9220
# Epoch 29/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2373 - accuracy: 0.9235
# Epoch 30/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2323 - accuracy: 0.9222
# Epoch 31/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.2286 - accuracy: 0.9252
# Epoch 32/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.2253 - accuracy: 0.9243
# Epoch 33/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2214 - accuracy: 0.9255
# Epoch 34/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2188 - accuracy: 0.9268
# Epoch 35/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2151 - accuracy: 0.9250
# Epoch 36/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2121 - accuracy: 0.9260
# Epoch 37/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2097 - accuracy: 0.9255
# Epoch 38/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2068 - accuracy: 0.9280
# Epoch 39/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2051 - accuracy: 0.9270
# Epoch 40/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2021 - accuracy: 0.9285
# Epoch 41/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1995 - accuracy: 0.9298
# Epoch 42/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1974 - accuracy: 0.9283
# Epoch 43/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1955 - accuracy: 0.9298
# Epoch 44/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1936 - accuracy: 0.9275
# Epoch 45/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1918 - accuracy: 0.9268
# Epoch 46/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1899 - accuracy: 0.9268
# Epoch 47/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1886 - accuracy: 0.9277
# Epoch 48/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1867 - accuracy: 0.9277
# Epoch 49/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1857 - accuracy: 0.9273
# Epoch 50/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1834 - accuracy: 0.9285
# Epoch 51/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1824 - accuracy: 0.9287
# Epoch 52/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1804 - accuracy: 0.9290
# Epoch 53/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1792 - accuracy: 0.9280
# Epoch 54/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1785 - accuracy: 0.9295
# Epoch 55/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1763 - accuracy: 0.9293
# Epoch 56/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1763 - accuracy: 0.9310
# Epoch 57/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1750 - accuracy: 0.9285
# Epoch 58/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1740 - accuracy: 0.9287
# Epoch 59/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1719 - accuracy: 0.9295
# Epoch 60/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1716 - accuracy: 0.9285
# Epoch 61/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1702 - accuracy: 0.9290
# Epoch 62/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1696 - accuracy: 0.9283
# Epoch 63/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1682 - accuracy: 0.9300
# Epoch 64/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1687 - accuracy: 0.9293
# Epoch 65/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1669 - accuracy: 0.9280
# Epoch 66/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1666 - accuracy: 0.9290
# Epoch 67/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1656 - accuracy: 0.9287
# Epoch 68/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1642 - accuracy: 0.9277
# Epoch 69/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1643 - accuracy: 0.9302
# Epoch 70/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1626 - accuracy: 0.9298
# Epoch 71/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1626 - accuracy: 0.9295
# Epoch 72/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1614 - accuracy: 0.9333
# Epoch 73/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1616 - accuracy: 0.9317
# Epoch 74/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1607 - accuracy: 0.9287
# Epoch 75/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1603 - accuracy: 0.9325
# Epoch 76/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1601 - accuracy: 0.9310
# Epoch 77/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1585 - accuracy: 0.9300
# Epoch 78/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1574 - accuracy: 0.9317
# Epoch 79/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1578 - accuracy: 0.9330
# Epoch 80/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1575 - accuracy: 0.9300
# Epoch 81/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1565 - accuracy: 0.9310
# Epoch 82/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1567 - accuracy: 0.9308
# Epoch 83/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1569 - accuracy: 0.9285
# Epoch 84/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1551 - accuracy: 0.9312
# Epoch 85/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1543 - accuracy: 0.9305
# Epoch 86/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1537 - accuracy: 0.9310
# Epoch 87/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1539 - accuracy: 0.9315
# Epoch 88/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1543 - accuracy: 0.9320
# Epoch 89/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1525 - accuracy: 0.9320
# Epoch 90/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1521 - accuracy: 0.9302
# Epoch 91/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1524 - accuracy: 0.9317
# Epoch 92/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1511 - accuracy: 0.9308
# Epoch 93/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1514 - accuracy: 0.9327
# Epoch 94/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1511 - accuracy: 0.9333
# Epoch 95/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1514 - accuracy: 0.9323
# Epoch 96/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1497 - accuracy: 0.9330
# Epoch 97/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1502 - accuracy: 0.9312
# Epoch 98/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1492 - accuracy: 0.9337
# Epoch 99/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1492 - accuracy: 0.9330
# Epoch 100/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1491 - accuracy: 0.9312
# Epoch 101/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1489 - accuracy: 0.9335
# Epoch 102/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1493 - accuracy: 0.9330
# Epoch 103/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1484 - accuracy: 0.9320
# Epoch 104/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1480 - accuracy: 0.9325
# Epoch 105/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1487 - accuracy: 0.9333
# Epoch 106/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1479 - accuracy: 0.9310
# Epoch 107/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1476 - accuracy: 0.9330
# Epoch 108/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1477 - accuracy: 0.9342
# Epoch 109/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1461 - accuracy: 0.9315
# Epoch 110/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1465 - accuracy: 0.9323
# Epoch 111/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1460 - accuracy: 0.9330
# Epoch 112/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1463 - accuracy: 0.9333
# Epoch 113/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1454 - accuracy: 0.9330
# Epoch 114/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1452 - accuracy: 0.9340
# Epoch 115/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1447 - accuracy: 0.9327
# Epoch 116/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1455 - accuracy: 0.9335
# Epoch 117/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1445 - accuracy: 0.9342
# Epoch 118/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1447 - accuracy: 0.9335
# Epoch 119/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1448 - accuracy: 0.9342
# Epoch 120/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1438 - accuracy: 0.9342
# Epoch 121/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1437 - accuracy: 0.9330
# Epoch 122/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1440 - accuracy: 0.9335
# Epoch 123/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1440 - accuracy: 0.9358
# Epoch 124/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1435 - accuracy: 0.9342
# Epoch 125/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1432 - accuracy: 0.9330
# Epoch 126/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1433 - accuracy: 0.9350
# Epoch 127/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1429 - accuracy: 0.9323
# Epoch 128/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1429 - accuracy: 0.9337
# Epoch 129/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1437 - accuracy: 0.9330
# Epoch 130/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1436 - accuracy: 0.9330
# Epoch 131/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1420 - accuracy: 0.9337
# Epoch 132/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1420 - accuracy: 0.9335
# Epoch 133/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1414 - accuracy: 0.9340
# Epoch 134/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1431 - accuracy: 0.9340
# Epoch 135/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1419 - accuracy: 0.9340
# Epoch 136/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1412 - accuracy: 0.9342
# Epoch 137/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1415 - accuracy: 0.9348
# Epoch 138/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1415 - accuracy: 0.9340
# Epoch 139/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1405 - accuracy: 0.9337
# Epoch 140/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1404 - accuracy: 0.9348
# Epoch 141/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1420 - accuracy: 0.9325
# Epoch 142/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1410 - accuracy: 0.9348
# Epoch 143/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1407 - accuracy: 0.9327
# Epoch 144/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1405 - accuracy: 0.9317
# Epoch 145/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1400 - accuracy: 0.9348
# Epoch 146/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1403 - accuracy: 0.9358
# Epoch 147/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1412 - accuracy: 0.9330
# Epoch 148/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1402 - accuracy: 0.9360
# Epoch 149/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1407 - accuracy: 0.9330
# Epoch 150/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1411 - accuracy: 0.9348
# Epoch 151/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1400 - accuracy: 0.9340
# Epoch 152/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1392 - accuracy: 0.9337
# Epoch 153/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1395 - accuracy: 0.9342
# Epoch 154/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1398 - accuracy: 0.9370
# Epoch 155/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1393 - accuracy: 0.9342
# Epoch 156/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1388 - accuracy: 0.9352
# Epoch 157/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1401 - accuracy: 0.9342
# Epoch 158/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1389 - accuracy: 0.9342
# Epoch 159/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1393 - accuracy: 0.9348
# Epoch 160/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1391 - accuracy: 0.9342
# Epoch 161/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1386 - accuracy: 0.9355
# Epoch 162/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1393 - accuracy: 0.9358
# Epoch 163/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1382 - accuracy: 0.9352
# Epoch 164/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1380 - accuracy: 0.9350
# Epoch 165/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1382 - accuracy: 0.9340
# Epoch 166/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1383 - accuracy: 0.9330
# Epoch 167/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1378 - accuracy: 0.9355
# Epoch 168/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1386 - accuracy: 0.9340
# Epoch 169/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1382 - accuracy: 0.9352
# Epoch 170/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1381 - accuracy: 0.9350
# Epoch 171/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1377 - accuracy: 0.9355
# Epoch 172/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1377 - accuracy: 0.9342
# Epoch 173/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1371 - accuracy: 0.9358
# Epoch 174/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1377 - accuracy: 0.9367
# Epoch 175/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1377 - accuracy: 0.9345
# Epoch 176/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1384 - accuracy: 0.9335
# Epoch 177/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1379 - accuracy: 0.9365
# Epoch 178/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1382 - accuracy: 0.9360
# Epoch 179/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1373 - accuracy: 0.9355
# Epoch 180/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1368 - accuracy: 0.9345
# Epoch 181/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1377 - accuracy: 0.9350
# Epoch 182/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1370 - accuracy: 0.9352
# Epoch 183/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1371 - accuracy: 0.9362
# Epoch 184/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1377 - accuracy: 0.9375
# Epoch 185/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1383 - accuracy: 0.9350
# Epoch 186/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1370 - accuracy: 0.9350
# Epoch 187/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1364 - accuracy: 0.9373
# Epoch 188/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1373 - accuracy: 0.9358
# Epoch 189/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1368 - accuracy: 0.9355
# Epoch 190/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1364 - accuracy: 0.9352
# Epoch 191/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1361 - accuracy: 0.9360
# Epoch 192/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1374 - accuracy: 0.9365
# Epoch 193/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1365 - accuracy: 0.9345
# Epoch 194/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1369 - accuracy: 0.9355
# Epoch 195/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1361 - accuracy: 0.9360
# Epoch 196/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1370 - accuracy: 0.9337
# Epoch 197/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1356 - accuracy: 0.9350
# Epoch 198/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1356 - accuracy: 0.9350
# Epoch 199/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1363 - accuracy: 0.9350
# Epoch 200/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1353 - accuracy: 0.9362
# Epoch 201/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1353 - accuracy: 0.9358
# Epoch 202/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1363 - accuracy: 0.9355
# Epoch 203/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1354 - accuracy: 0.9365
# Epoch 204/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1362 - accuracy: 0.9327
# Epoch 205/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1351 - accuracy: 0.9365
# Epoch 206/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1357 - accuracy: 0.9358
# Epoch 207/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1345 - accuracy: 0.9360
# Epoch 208/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1365 - accuracy: 0.9345
# Epoch 209/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1349 - accuracy: 0.9367
# Epoch 210/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1350 - accuracy: 0.9362
# Epoch 211/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1346 - accuracy: 0.9365
# Epoch 212/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1347 - accuracy: 0.9360
# Epoch 213/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1346 - accuracy: 0.9360
# Epoch 214/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1354 - accuracy: 0.9342
# Epoch 215/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1345 - accuracy: 0.9355
# Epoch 216/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1345 - accuracy: 0.9365
# Epoch 217/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1338 - accuracy: 0.9367
# Epoch 218/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1347 - accuracy: 0.9373
# Epoch 219/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1362 - accuracy: 0.9352
# Epoch 220/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1355 - accuracy: 0.9370
# Epoch 221/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1363 - accuracy: 0.9340
# Epoch 222/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1338 - accuracy: 0.9362
# Epoch 223/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1339 - accuracy: 0.9345
# Epoch 224/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1341 - accuracy: 0.9355
# Epoch 225/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1351 - accuracy: 0.9383
# Epoch 226/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1340 - accuracy: 0.9358
# Epoch 227/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1341 - accuracy: 0.9352
# Epoch 228/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1341 - accuracy: 0.9365
# Epoch 229/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1337 - accuracy: 0.9367
# Epoch 230/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1334 - accuracy: 0.9348
# Epoch 231/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1334 - accuracy: 0.9362
# Epoch 232/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1338 - accuracy: 0.9355
# Epoch 233/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1327 - accuracy: 0.9365
# Epoch 234/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1333 - accuracy: 0.9373
# Epoch 235/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1335 - accuracy: 0.9358
# Epoch 236/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1343 - accuracy: 0.9362
# Epoch 237/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1335 - accuracy: 0.9350
# Epoch 238/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1331 - accuracy: 0.9365
# Epoch 239/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1333 - accuracy: 0.9355
# Epoch 240/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1327 - accuracy: 0.9377
# Epoch 241/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1326 - accuracy: 0.9355
# Epoch 242/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1337 - accuracy: 0.9365
# Epoch 243/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1326 - accuracy: 0.9352
# Epoch 244/250
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1330 - accuracy: 0.9362
# Epoch 245/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1330 - accuracy: 0.9352
# Epoch 246/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1332 - accuracy: 0.9373
# Epoch 247/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1326 - accuracy: 0.9358
# Epoch 248/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1340 - accuracy: 0.9335
# Epoch 249/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1322 - accuracy: 0.9352
# Epoch 250/250
# 63/63 [==============================] - 0s 1ms/step - loss: 0.1338 - accuracy: 0.9365

# %%
print(model)
model.evaluate(X_Train, Y_train)
print(model.metrics_names)
#%% Predicting the Test set results
# Out:
# <tensorflow.python.keras.engine.sequential.Sequential object at 0x0000024259C68B80>
# 125/125 [==============================] - 0s 896us/step - loss: 0.1306 - accuracy: 0.9370
# ['loss', 'accuracy']

# %%
from sklearn import metrics

# %%
y_pred = (model.predict(X_Test) > 0.5)
#%% Making the Confusion Matrix
cm = metrics.confusion_matrix(Y_test, y_pred)
print("Confusion matrix\n",cm)

sensitivity = cm[0,0]/(cm[0,0]+cm[0,1])
print('Sensitivity :', sensitivity )

specificity = cm[1,1]/(cm[1,0]+cm[1,1])
print('Specificity :', specificity)
#%% 
print("Precision",metrics.precision_score(Y_test, y_pred, average=None))
print("Accuracy",metrics.accuracy_score(Y_test, y_pred))
print("F1",metrics.f1_score(Y_test, y_pred, average=None))
# Out:
# Confusion matrix
#  [[464  36]
#  [ 35 465]]
# Sensitivity : 0.928
# Specificity : 0.93
# Precision [0.92985972 0.92814371]
# Accuracy 0.929
# F1 [0.92892893 0.92907093]

# %%
import numpy as np

# %% [markdown]
# fallas=np.array(labels,dtype='<U256')
# y_pred=y_pred.reshape(len(y_pred))
# print(np.shape(y_pred))
# print(np.shape(Y_Test))
# for i in range(len(y_pred)):
#     if(y_pred[i]!=Y_Test[i]>0.5):
#         fallas=np.vstack((fallas,testDataset.iloc[i].to_numpy()))
#
# y_pred = (model.predict(X_Train) > 0.5).reshape(len(X_Train))
# for i in range(len(y_pred)):
#     if(y_pred[i]!=Y_Train[i]>0.5):
#         fallas=np.vstack((fallas,trainDataset.iloc[i].to_numpy()))
#
# asd="fallasEval.csv"
# print("Fallas",len(fallas))
# np.savetxt(asd,fallas,delimiter=",", fmt="%s")

# %% [markdown]
# from keras.models import load_model
#
# model.save('my_model.h5')  # creates a HDF5 file 'my_model.h5'
